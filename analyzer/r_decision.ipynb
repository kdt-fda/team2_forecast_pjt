# %%
bok_meeting_dates = [
    # 2025년 (8회 예정)
    '2025-01-16', '2025-02-20', '2025-04-10', '2025-05-22', 
    '2025-07-10', '2025-08-28', '2025-10-23', '2025-11-27',
    
    # 2024년 (8회)
    '2024-01-11', '2024-02-22', '2024-04-12', '2024-05-23', 
    '2024-07-11', '2024-08-22', '2024-10-11', '2024-11-28',
    
    # 2023년 (8회)
    '2023-01-13', '2023-02-23', '2023-04-13', '2023-05-25', 
    '2023-07-13', '2023-08-24', '2023-10-19', '2023-11-30',
    
    # 2022년 (8회)
    '2022-01-14', '2022-02-24', '2022-04-14', '2022-05-26', 
    '2022-07-13', '2022-08-25', '2022-10-12', '2022-11-24',
    
    # 2021년 (8회)
    '2021-01-15', '2021-02-25', '2021-04-15', '2021-05-27', 
    '2021-07-15', '2021-08-26', '2021-10-12', '2021-11-25',
    
    # 2020년 (8회 + 임시회의 3.16, 5.28 제외/정규만 포함)
    '2020-01-17', '2020-02-27', '2020-04-09', '2020-05-28', 
    '2020-07-16', '2020-08-27', '2020-10-14', '2020-11-26',
    
    # 2019년 (8회)
    '2019-01-24', '2019-02-28', '2019-04-18', '2019-05-31', 
    '2019-07-18', '2019-08-30', '2019-10-16', '2019-11-29',
    
    # 2018년 (8회)
    '2018-01-18', '2018-02-27', '2018-04-12', '2018-05-24', 
    '2018-07-12', '2018-08-31', '2018-10-18', '2018-11-30',
    
    # 2017년 (8회 - 이때부터 연 8회로 변경)
    '2017-01-13', '2017-02-23', '2017-04-13', '2017-05-25', 
    '2017-07-13', '2017-08-31', '2017-10-19', '2017-11-30',
    
    # 2016년 (12회 - 마지막 연 12회 실시 연도)
    '2016-01-14', '2016-02-16', '2016-03-10', '2016-04-19', 
    '2016-05-13', '2016-06-09', '2016-07-14', '2016-08-11', 
    '2016-09-09', '2016-10-13', '2016-11-11', '2016-12-15',
    
    # 2015년 (12회)
    '2015-01-15', '2015-02-17', '2015-03-12', '2015-04-09', 
    '2015-05-15', '2015-06-11', '2015-07-09', '2015-08-13', 
    '2015-09-11', '2015-10-15', '2015-11-12', '2015-12-10',
    
    # 2014년 (12회)
    '2014-01-09', '2014-02-13', '2014-03-13', '2014-04-10', 
    '2014-05-09', '2014-06-12', '2014-07-10', '2014-08-14', 
    '2014-09-12', '2014-10-15', '2014-11-13', '2014-12-11',
    
    # 2013년 (12회)
    '2013-01-11', '2013-02-14', '2013-03-14', '2013-04-11', 
    '2013-05-09', '2013-06-13', '2013-07-11', '2013-08-08', 
    '2013-09-12', '2013-10-10', '2013-11-14', '2013-12-12',
    
    # 2012년 (12회)
    '2012-01-13', '2012-02-09', '2012-03-08', '2012-04-13', 
    '2012-05-10', '2012-06-08', '2012-07-12', '2012-08-09', 
    '2012-09-13', '2012-10-11', '2012-11-09', '2012-12-13'
]
